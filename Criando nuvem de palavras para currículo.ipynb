# %%
#!pip install pdfplumber

# %%
import pdfplumber
import nltk

# %%
arquivoPDF = pdfplumber.open('Curriculum_Vitae.pdf')

# %%
primeira_pagina = arquivoPDF.pages[1] # escolhe qual página deseja analisar
textoCRU = primeira_pagina.extract_text()
textoCRU
# Out:
# 'Tecnologias e Linguagens de Programação\n○␣ Python\n○␣ Git, Gitlab, Github\n○␣ R\n○␣ SQL\nIdioma\n○␣ Inglês Básico\nCertiﬁcações\nGitlab CI: Pipelines, Continuous Delivery e Deployment, Udemy - Em andamento.\nDevOps: Certiﬁed Jenkins Engineer, Udemy - Em andamento.\nPython para Data Science e Machine Learning, Udemy - Em andamento.\n○␣ Aprender a utilizar ferramentas de manipulação e visualização de dados em Python - Pandas, Matplotlib,\nseaborn, Plotly.\n○␣ Estudo dos principais algoritmos de Aprendizado de Máquina e sua aplicação no Python.\n○␣ Elaborar projetos de análise e ciência de dados.\n○␣ Sistemas de Recomendação\n○␣ Processamento de Linguagem Natural\nImersão FLAI em Projetos de Data Science, FLAI. - Concluído em novembro de 2021.\n○␣ Desenvolvimento de quatro projetos: Dashboard ﬁnanceiro com dados de cartão de crédito em POWER BI\n○␣ Classiﬁcador de Match de Currículos com vagas utilizando NLTK Python\n○␣ Tratamento e construção de modelos utilizando o Pycaret\n○␣ Modelo para Previsao de Fraudes em Cartao de Credito.\nBig Data Fundamentos 2.0, Data Science Academy - Concluído em fevereiro de 2021.\n○␣ Sistemas de Armazenamento de Dados\n○␣ Cloud Computing\n○␣ Extract, transform, load (ETL)\nInteligência Artiﬁcial Fundamentos 2.0, Data Science Academy - Concluído em fevereiro de 2021.\n○␣ Conceitos, soluções e aplicações da IA na sociedade\n○␣ Aprendizado de Máquina e Redes Neurais\nIntrodução à Ciência de Dados 2.0, Data Science Academy - Concluído em janeiro de 2021.\n○␣ Compreender o conceito de Ciência de Dados e sua relação com a estatística\n○␣ Aprendizado de Máquina e MLops\n○␣ Aplicações e Ciclo de Vida de Projetos.\n2/2'

# %%
arquivoPDF.metadata
# Out:
# {'Author': 'Danilo Santos',
#  'CreationDate': 'D:20211126165304Z',
#  'Creator': "LaTeX with 'moderncv' package",
#  'Keywords': 'Danilo Santos, curriculum vitæ, resumé',
#  'ModDate': 'D:20211126165304Z',
#  'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2',
#  'Producer': 'pdfTeX-1.40.21',
#  'Subject': 'Resumé of Danilo Santos',
#  'Title': 'Danilo Santos – ',
#  'Trapped': 'False'}

# %%
arquivoPDF.hyperlinks
# Out:
# [{'page_number': 1,
#   'object_type': 'annot',
#   'x0': Decimal('293.202'),
#   'y0': Decimal('696.722'),
#   'x1': Decimal('429.134'),
#   'y1': Decimal('710.950'),
#   'doctop': Decimal('130.940'),
#   'top': Decimal('130.940'),
#   'bottom': Decimal('145.168'),
#   'width': Decimal('135.932'),
#   'height': Decimal('14.228'),
#   'uri': 'mailto:danilosantosvieir2@gmail.com',
#   'title': None,
#   'contents': None,
#   'data': {'A': {'S': /'URI',
#     'Type': /'Action',
#     'URI': b'mailto:danilosantosvieir2@gmail.com'},
#    'Border': [0, 0, 0],
#    'C': [0, 1, 1],
#    'H': /'I',
#    'Rect': [293.202, 696.722, 429.134, 710.95],
#    'Subtype': /'Link',
#    'Type': /'Annot'}},
#  {'page_number': 1,
#   'object_type': 'annot',
#   'x0': Decimal('254.838'),
#   'y0': Decimal('684.722'),
#   'x1': Decimal('291.195'),
#   'y1': Decimal('695.823'),
#   'doctop': Decimal('146.067'),
#   'top': Decimal('146.067'),
#   'bottom': Decimal('157.168'),
#   'width': Decimal('36.357'),
#   'height': Decimal('11.101'),
#   'uri': 'https://github.com/Danilosvsv/ ',
#   'title': None,
#   'contents': None,
#   'data': {'A': {'S': /'URI',
#     'Type': /'Action',
#     'URI': b'https://github.com/Danilosvsv/ '},
#    'Border': [0, 0, 0],
#    'C': [0, 1, 1],
#    'H': /'I',
#    'Rect': [254.838, 684.722, 291.195, 695.823],
#    'Subtype': /'Link',
#    'Type': /'Annot'}},
#  {'page_number': 1,
#   'object_type': 'annot',
#   'x0': Decimal('302.188'),
#   'y0': Decimal('684.722'),
#   'x1': Decimal('346.150'),
#   'y1': Decimal('695.823'),
#   'doctop': Decimal('146.067'),
#   'top': Decimal('146.067'),
#   'bottom': Decimal('157.168'),
#   'width': Decimal('43.962'),
#   'height': Decimal('11.101'),
#   'uri': 'https://www.linkedin.com/in/danilo-santos-21a6421b0/',
#   'title': None,
#   'contents': None,
#   'data': {'A': {'S': /'URI',
#     'Type': /'Action',
#     'URI': b'https://www.linkedin.com/in/danilo-santos-21a6421b0/'},
#    'Border': [0, 0, 0],
#    'C': [0, 1, 1],
#    'H': /'I',
#    'Rect': [302.188, 684.722, 346.15, 695.823],
#    'Subtype': /'Link',
#    'Type': /'Annot'}}]

# %% [markdown]
# ## **Pré-processamento de Texto**

# %%
# A função word_tokenize() quebra o texto em palavras individuais.
nltk.download('punkt')
lista_de_palavras = nltk.tokenize.word_tokenize(textoCRU)
lista_de_palavras
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\danil\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Tecnologias',
#  'e',
#  'Linguagens',
#  'de',
#  'Programação',
#  '○␣',
#  'Python',
#  '○␣',
#  'Git',
#  ',',
#  'Gitlab',
#  ',',
#  'Github',
#  '○␣',
#  'R',
#  '○␣',
#  'SQL',
#  'Idioma',
#  '○␣',
#  'Inglês',
#  'Básico',
#  'Certiﬁcações',
#  'Gitlab',
#  'CI',
#  ':',
#  'Pipelines',
#  ',',
#  'Continuous',
#  'Delivery',
#  'e',
#  'Deployment',
#  ',',
#  'Udemy',
#  '-',
#  'Em',
#  'andamento',
#  '.',
#  'DevOps',
#  ':',
#  'Certiﬁed',
#  'Jenkins',
#  'Engineer',
#  ',',
#  'Udemy',
#  '-',
#  'Em',
#  'andamento',
#  '.',
#  'Python',
#  'para',
#  'Data',
#  'Science',
#  'e',
#  'Machine',
#  'Learning',
#  ',',
#  'Udemy',
#  '-',
#  'Em',
#  'andamento',
#  '.',
#  '○␣',
#  'Aprender',
#  'a',
#  'utilizar',
#  'ferramentas',
#  'de',
#  'manipulação',
#  'e',
#  'visualização',
#  'de',
#  'dados',
#  'em',
#  'Python',
#  '-',
#  'Pandas',
#  ',',
#  'Matplotlib',
#  ',',
#  'seaborn',
#  ',',
#  'Plotly',
#  '.',
#  '○␣',
#  'Estudo',
#  'dos',
#  'principais',
#  'algoritmos',
#  'de',
#  'Aprendizado',
#  'de',
#  'Máquina',
#  'e',
#  'sua',
#  'aplicação',
#  'no',
#  'Python',
#  '.',
#  '○␣',
#  'Elaborar',
#  'projetos',
#  'de',
#  'análise',
#  'e',
#  'ciência',
#  'de',
#  'dados',
#  '.',
#  '○␣',
#  'Sistemas',
#  'de',
#  'Recomendação',
#  '○␣',
#  'Processamento',
#  'de',
#  'Linguagem',
#  'Natural',
#  'Imersão',
#  'FLAI',
#  'em',
#  'Projetos',
#  'de',
#  'Data',
#  'Science',
#  ',',
#  'FLAI',
#  '.',
#  '-',
#  'Concluído',
#  'em',
#  'novembro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'Desenvolvimento',
#  'de',
#  'quatro',
#  'projetos',
#  ':',
#  'Dashboard',
#  'ﬁnanceiro',
#  'com',
#  'dados',
#  'de',
#  'cartão',
#  'de',
#  'crédito',
#  'em',
#  'POWER',
#  'BI',
#  '○␣',
#  'Classiﬁcador',
#  'de',
#  'Match',
#  'de',
#  'Currículos',
#  'com',
#  'vagas',
#  'utilizando',
#  'NLTK',
#  'Python',
#  '○␣',
#  'Tratamento',
#  'e',
#  'construção',
#  'de',
#  'modelos',
#  'utilizando',
#  'o',
#  'Pycaret',
#  '○␣',
#  'Modelo',
#  'para',
#  'Previsao',
#  'de',
#  'Fraudes',
#  'em',
#  'Cartao',
#  'de',
#  'Credito',
#  '.',
#  'Big',
#  'Data',
#  'Fundamentos',
#  '2.0',
#  ',',
#  'Data',
#  'Science',
#  'Academy',
#  '-',
#  'Concluído',
#  'em',
#  'fevereiro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'Sistemas',
#  'de',
#  'Armazenamento',
#  'de',
#  'Dados',
#  '○␣',
#  'Cloud',
#  'Computing',
#  '○␣',
#  'Extract',
#  ',',
#  'transform',
#  ',',
#  'load',
#  '(',
#  'ETL',
#  ')',
#  'Inteligência',
#  'Artiﬁcial',
#  'Fundamentos',
#  '2.0',
#  ',',
#  'Data',
#  'Science',
#  'Academy',
#  '-',
#  'Concluído',
#  'em',
#  'fevereiro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'Conceitos',
#  ',',
#  'soluções',
#  'e',
#  'aplicações',
#  'da',
#  'IA',
#  'na',
#  'sociedade',
#  '○␣',
#  'Aprendizado',
#  'de',
#  'Máquina',
#  'e',
#  'Redes',
#  'Neurais',
#  'Introdução',
#  'à',
#  'Ciência',
#  'de',
#  'Dados',
#  '2.0',
#  ',',
#  'Data',
#  'Science',
#  'Academy',
#  '-',
#  'Concluído',
#  'em',
#  'janeiro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'Compreender',
#  'o',
#  'conceito',
#  'de',
#  'Ciência',
#  'de',
#  'Dados',
#  'e',
#  'sua',
#  'relação',
#  'com',
#  'a',
#  'estatística',
#  '○␣',
#  'Aprendizado',
#  'de',
#  'Máquina',
#  'e',
#  'MLops',
#  '○␣',
#  'Aplicações',
#  'e',
#  'Ciclo',
#  'de',
#  'Vida',
#  'de',
#  'Projetos',
#  '.',
#  '2/2']

# %%
# Padronizando as palavras em lowercase (apenas letras minúsculas)
lista_de_palavras = [palavra.lower() for palavra in lista_de_palavras]
lista_de_palavras
# Out:
# ['tecnologias',
#  'e',
#  'linguagens',
#  'de',
#  'programação',
#  '○␣',
#  'python',
#  '○␣',
#  'git',
#  ',',
#  'gitlab',
#  ',',
#  'github',
#  '○␣',
#  'r',
#  '○␣',
#  'sql',
#  'idioma',
#  '○␣',
#  'inglês',
#  'básico',
#  'certiﬁcações',
#  'gitlab',
#  'ci',
#  ':',
#  'pipelines',
#  ',',
#  'continuous',
#  'delivery',
#  'e',
#  'deployment',
#  ',',
#  'udemy',
#  '-',
#  'em',
#  'andamento',
#  '.',
#  'devops',
#  ':',
#  'certiﬁed',
#  'jenkins',
#  'engineer',
#  ',',
#  'udemy',
#  '-',
#  'em',
#  'andamento',
#  '.',
#  'python',
#  'para',
#  'data',
#  'science',
#  'e',
#  'machine',
#  'learning',
#  ',',
#  'udemy',
#  '-',
#  'em',
#  'andamento',
#  '.',
#  '○␣',
#  'aprender',
#  'a',
#  'utilizar',
#  'ferramentas',
#  'de',
#  'manipulação',
#  'e',
#  'visualização',
#  'de',
#  'dados',
#  'em',
#  'python',
#  '-',
#  'pandas',
#  ',',
#  'matplotlib',
#  ',',
#  'seaborn',
#  ',',
#  'plotly',
#  '.',
#  '○␣',
#  'estudo',
#  'dos',
#  'principais',
#  'algoritmos',
#  'de',
#  'aprendizado',
#  'de',
#  'máquina',
#  'e',
#  'sua',
#  'aplicação',
#  'no',
#  'python',
#  '.',
#  '○␣',
#  'elaborar',
#  'projetos',
#  'de',
#  'análise',
#  'e',
#  'ciência',
#  'de',
#  'dados',
#  '.',
#  '○␣',
#  'sistemas',
#  'de',
#  'recomendação',
#  '○␣',
#  'processamento',
#  'de',
#  'linguagem',
#  'natural',
#  'imersão',
#  'flai',
#  'em',
#  'projetos',
#  'de',
#  'data',
#  'science',
#  ',',
#  'flai',
#  '.',
#  '-',
#  'concluído',
#  'em',
#  'novembro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'desenvolvimento',
#  'de',
#  'quatro',
#  'projetos',
#  ':',
#  'dashboard',
#  'ﬁnanceiro',
#  'com',
#  'dados',
#  'de',
#  'cartão',
#  'de',
#  'crédito',
#  'em',
#  'power',
#  'bi',
#  '○␣',
#  'classiﬁcador',
#  'de',
#  'match',
#  'de',
#  'currículos',
#  'com',
#  'vagas',
#  'utilizando',
#  'nltk',
#  'python',
#  '○␣',
#  'tratamento',
#  'e',
#  'construção',
#  'de',
#  'modelos',
#  'utilizando',
#  'o',
#  'pycaret',
#  '○␣',
#  'modelo',
#  'para',
#  'previsao',
#  'de',
#  'fraudes',
#  'em',
#  'cartao',
#  'de',
#  'credito',
#  '.',
#  'big',
#  'data',
#  'fundamentos',
#  '2.0',
#  ',',
#  'data',
#  'science',
#  'academy',
#  '-',
#  'concluído',
#  'em',
#  'fevereiro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'sistemas',
#  'de',
#  'armazenamento',
#  'de',
#  'dados',
#  '○␣',
#  'cloud',
#  'computing',
#  '○␣',
#  'extract',
#  ',',
#  'transform',
#  ',',
#  'load',
#  '(',
#  'etl',
#  ')',
#  'inteligência',
#  'artiﬁcial',
#  'fundamentos',
#  '2.0',
#  ',',
#  'data',
#  'science',
#  'academy',
#  '-',
#  'concluído',
#  'em',
#  'fevereiro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'conceitos',
#  ',',
#  'soluções',
#  'e',
#  'aplicações',
#  'da',
#  'ia',
#  'na',
#  'sociedade',
#  '○␣',
#  'aprendizado',
#  'de',
#  'máquina',
#  'e',
#  'redes',
#  'neurais',
#  'introdução',
#  'à',
#  'ciência',
#  'de',
#  'dados',
#  '2.0',
#  ',',
#  'data',
#  'science',
#  'academy',
#  '-',
#  'concluído',
#  'em',
#  'janeiro',
#  'de',
#  '2021',
#  '.',
#  '○␣',
#  'compreender',
#  'o',
#  'conceito',
#  'de',
#  'ciência',
#  'de',
#  'dados',
#  'e',
#  'sua',
#  'relação',
#  'com',
#  'a',
#  'estatística',
#  '○␣',
#  'aprendizado',
#  'de',
#  'máquina',
#  'e',
#  'mlops',
#  '○␣',
#  'aplicações',
#  'e',
#  'ciclo',
#  'de',
#  'vida',
#  'de',
#  'projetos',
#  '.',
#  '2/2']

# %%
#Criando uma lista que contém pontuação que desejamos remover
pontuacao = ['(',')',';',':','[',']',',']

# %%
#Criando uma lista de stop words "a", "de", "um"que não tem valor como palavra
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('portuguese')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\danil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['de',
#  'a',
#  'o',
#  'que',
#  'e',
#  'é',
#  'do',
#  'da',
#  'em',
#  'um',
#  'para',
#  'com',
#  'não',
#  'uma',
#  'os',
#  'no',
#  'se',
#  'na',
#  'por',
#  'mais',
#  'as',
#  'dos',
#  'como',
#  'mas',
#  'ao',
#  'ele',
#  'das',
#  'à',
#  'seu',
#  'sua',
#  'ou',
#  'quando',
#  'muito',
#  'nos',
#  'já',
#  'eu',
#  'também',
#  'só',
#  'pelo',
#  'pela',
#  'até',
#  'isso',
#  'ela',
#  'entre',
#  'depois',
#  'sem',
#  'mesmo',
#  'aos',
#  'seus',
#  'quem',
#  'nas',
#  'me',
#  'esse',
#  'eles',
#  'você',
#  'essa',
#  'num',
#  'nem',
#  'suas',
#  'meu',
#  'às',
#  'minha',
#  'numa',
#  'pelos',
#  'elas',
#  'qual',
#  'nós',
#  'lhe',
#  'deles',
#  'essas',
#  'esses',
#  'pelas',
#  'este',
#  'dele',
#  'tu',
#  'te',
#  'vocês',
#  'vos',
#  'lhes',
#  'meus',
#  'minhas',
#  'teu',
#  'tua',
#  'teus',
#  'tuas',
#  'nosso',
#  'nossa',
#  'nossos',
#  'nossas',
#  'dela',
#  'delas',
#  'esta',
#  'estes',
#  'estas',
#  'aquele',
#  'aquela',
#  'aqueles',
#  'aquelas',
#  'isto',
#  'aquilo',
#  'estou',
#  'está',
#  'estamos',
#  'estão',
#  'estive',
#  'esteve',
#  'estivemos',
#  'estiveram',
#  'estava',
#  'estávamos',
#  'estavam',
#  'estivera',
#  'estivéramos',
#  'esteja',
#  'estejamos',
#  'estejam',
#  'estivesse',
#  'estivéssemos',
#  'estivessem',
#  'estiver',
#  'estivermos',
#  'estiverem',
#  'hei',
#  'há',
#  'havemos',
#  'hão',
#  'houve',
#  'houvemos',
#  'houveram',
#  'houvera',
#  'houvéramos',
#  'haja',
#  'hajamos',
#  'hajam',
#  'houvesse',
#  'houvéssemos',
#  'houvessem',
#  'houver',
#  'houvermos',
#  'houverem',
#  'houverei',
#  'houverá',
#  'houveremos',
#  'houverão',
#  'houveria',
#  'houveríamos',
#  'houveriam',
#  'sou',
#  'somos',
#  'são',
#  'era',
#  'éramos',
#  'eram',
#  'fui',
#  'foi',
#  'fomos',
#  'foram',
#  'fora',
#  'fôramos',
#  'seja',
#  'sejamos',
#  'sejam',
#  'fosse',
#  'fôssemos',
#  'fossem',
#  'for',
#  'formos',
#  'forem',
#  'serei',
#  'será',
#  'seremos',
#  'serão',
#  'seria',
#  'seríamos',
#  'seriam',
#  'tenho',
#  'tem',
#  'temos',
#  'tém',
#  'tinha',
#  'tínhamos',
#  'tinham',
#  'tive',
#  'teve',
#  'tivemos',
#  'tiveram',
#  'tivera',
#  'tivéramos',
#  'tenha',
#  'tenhamos',
#  'tenham',
#  'tivesse',
#  'tivéssemos',
#  'tivessem',
#  'tiver',
#  'tivermos',
#  'tiverem',
#  'terei',
#  'terá',
#  'teremos',
#  'terão',
#  'teria',
#  'teríamos',
#  'teriam']

# %%
#criando uma lista de palavra sem stopword e pontuações
keywords = [palavra for palavra in lista_de_palavras if not palavra in stop_words and not palavra in pontuacao]
keywords
# Out:
# ['tecnologias',
#  'linguagens',
#  'programação',
#  '○␣',
#  'python',
#  '○␣',
#  'git',
#  'gitlab',
#  'github',
#  '○␣',
#  'r',
#  '○␣',
#  'sql',
#  'idioma',
#  '○␣',
#  'inglês',
#  'básico',
#  'certiﬁcações',
#  'gitlab',
#  'ci',
#  'pipelines',
#  'continuous',
#  'delivery',
#  'deployment',
#  'udemy',
#  '-',
#  'andamento',
#  '.',
#  'devops',
#  'certiﬁed',
#  'jenkins',
#  'engineer',
#  'udemy',
#  '-',
#  'andamento',
#  '.',
#  'python',
#  'data',
#  'science',
#  'machine',
#  'learning',
#  'udemy',
#  '-',
#  'andamento',
#  '.',
#  '○␣',
#  'aprender',
#  'utilizar',
#  'ferramentas',
#  'manipulação',
#  'visualização',
#  'dados',
#  'python',
#  '-',
#  'pandas',
#  'matplotlib',
#  'seaborn',
#  'plotly',
#  '.',
#  '○␣',
#  'estudo',
#  'principais',
#  'algoritmos',
#  'aprendizado',
#  'máquina',
#  'aplicação',
#  'python',
#  '.',
#  '○␣',
#  'elaborar',
#  'projetos',
#  'análise',
#  'ciência',
#  'dados',
#  '.',
#  '○␣',
#  'sistemas',
#  'recomendação',
#  '○␣',
#  'processamento',
#  'linguagem',
#  'natural',
#  'imersão',
#  'flai',
#  'projetos',
#  'data',
#  'science',
#  'flai',
#  '.',
#  '-',
#  'concluído',
#  'novembro',
#  '2021',
#  '.',
#  '○␣',
#  'desenvolvimento',
#  'quatro',
#  'projetos',
#  'dashboard',
#  'ﬁnanceiro',
#  'dados',
#  'cartão',
#  'crédito',
#  'power',
#  'bi',
#  '○␣',
#  'classiﬁcador',
#  'match',
#  'currículos',
#  'vagas',
#  'utilizando',
#  'nltk',
#  'python',
#  '○␣',
#  'tratamento',
#  'construção',
#  'modelos',
#  'utilizando',
#  'pycaret',
#  '○␣',
#  'modelo',
#  'previsao',
#  'fraudes',
#  'cartao',
#  'credito',
#  '.',
#  'big',
#  'data',
#  'fundamentos',
#  '2.0',
#  'data',
#  'science',
#  'academy',
#  '-',
#  'concluído',
#  'fevereiro',
#  '2021',
#  '.',
#  '○␣',
#  'sistemas',
#  'armazenamento',
#  'dados',
#  '○␣',
#  'cloud',
#  'computing',
#  '○␣',
#  'extract',
#  'transform',
#  'load',
#  'etl',
#  'inteligência',
#  'artiﬁcial',
#  'fundamentos',
#  '2.0',
#  'data',
#  'science',
#  'academy',
#  '-',
#  'concluído',
#  'fevereiro',
#  '2021',
#  '.',
#  '○␣',
#  'conceitos',
#  'soluções',
#  'aplicações',
#  'ia',
#  'sociedade',
#  '○␣',
#  'aprendizado',
#  'máquina',
#  'redes',
#  'neurais',
#  'introdução',
#  'ciência',
#  'dados',
#  '2.0',
#  'data',
#  'science',
#  'academy',
#  '-',
#  'concluído',
#  'janeiro',
#  '2021',
#  '.',
#  '○␣',
#  'compreender',
#  'conceito',
#  'ciência',
#  'dados',
#  'relação',
#  'estatística',
#  '○␣',
#  'aprendizado',
#  'máquina',
#  'mlops',
#  '○␣',
#  'aplicações',
#  'ciclo',
#  'vida',
#  'projetos',
#  '.',
#  '2/2']

# %%
#numero de palavras das reviews
len(keywords)
# Out:
# 203

# %%
# concatenar as palavras
textocv = " ".join(s for s in keywords)
textocv
# Out:
# 'tecnologias linguagens programação ○␣ python ○␣ git gitlab github ○␣ r ○␣ sql idioma ○␣ inglês básico certiﬁcações gitlab ci pipelines continuous delivery deployment udemy - andamento . devops certiﬁed jenkins engineer udemy - andamento . python data science machine learning udemy - andamento . ○␣ aprender utilizar ferramentas manipulação visualização dados python - pandas matplotlib seaborn plotly . ○␣ estudo principais algoritmos aprendizado máquina aplicação python . ○␣ elaborar projetos análise ciência dados . ○␣ sistemas recomendação ○␣ processamento linguagem natural imersão flai projetos data science flai . - concluído novembro 2021 . ○␣ desenvolvimento quatro projetos dashboard ﬁnanceiro dados cartão crédito power bi ○␣ classiﬁcador match currículos vagas utilizando nltk python ○␣ tratamento construção modelos utilizando pycaret ○␣ modelo previsao fraudes cartao credito . big data fundamentos 2.0 data science academy - concluído fevereiro 2021 . ○␣ sistemas armazenamento dados ○␣ cloud computing ○␣ extract transform load etl inteligência artiﬁcial fundamentos 2.0 data science academy - concluído fevereiro 2021 . ○␣ conceitos soluções aplicações ia sociedade ○␣ aprendizado máquina redes neurais introdução ciência dados 2.0 data science academy - concluído janeiro 2021 . ○␣ compreender conceito ciência dados relação estatística ○␣ aprendizado máquina mlops ○␣ aplicações ciclo vida projetos . 2/2'

# %%
# gerar uma wordcloud

from wordcloud import WordCloud

wordcloud = WordCloud(background_color = '#0f54c9', 
                      max_font_size = 150, 
                      width = 1280, 
                      height = 720, 
                      colormap= 'Blues').generate(textocv) 

# mostrar a imagem final
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
wordcloud.to_file("wordcloud.png")
plt.show()
